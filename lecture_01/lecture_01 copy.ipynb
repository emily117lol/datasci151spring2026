# %% [markdown]
# These are where lecture notes will be written, describing what's happening in the code cells

# %% [markdown]
# There are different ways of changing fonts...
#
#
# <font size = "4">
#
# Font size 4
#
# other text
# other text
#
# <font size = "10">
# Font size 10
#
# other text
# <font size = "1">
#
# small text

# %% [markdown]
# # Big text
#
# ## slightly smaller
#
#
# ###### smallest

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## Additional notes here, explaining something

# %%
print("Another python command!")
# Out:
# Another python command!

# %% [markdown]
# Content
#
# Lecture 1 Printing stuff
# Lecture 2 imporitng math, statistics, pandas, matplotlib, carfeatures = pd.read_csv("data/features.csv"), freq table, cross tab,
#
# plt.scatter(x = carfeatures['weight'], y = carfeatures['mpg'])
# plt.xlabel("Weight")
# plt.ylabel("mpg")
# plt.title("Relationship between Weight and Gas Mileage of cars")
# plt.show()
#
#
# Lecture 4
#
# Type, variables, rounding numbers
#
# fulton_cost = round(fulton_cost, 2)
#
# lists favorite_movies = ["the lego movie","lego batman movie", "lego ninjago movie"]
#
# print(favorite_movies[0])
#
# Lecture 5
#
# Tuples and strings
# tuple_of_numbers = (5, 3, 2, 0)
#
# Concatenation
# list_1 = [2, 3, 5, 11]
# list_2 = [1, -4, 2, 0]
#
# list_3 = list_1 + list_2
#
# tuple_1 = (1, 2, 0, 9, 8)
# tuple_2 = (-1, -50)
#
# print(tuple_1 + tuple_2)
#
# Lecture 6
#
# Floats, bar graph
# categories = ["freshman", "sophomore", "juniors", "seniors"]
# count = [22, 21, 31, 25]
#
# plt.bar(x=categories, height=count)
# plt.show()
#
# Arrays
#
# list_of_numbers = [5.6, 2.9, 9.7, -10, 0, 3]
# array_of_numbers = np.array(list_of_numbers)
#
# array_1 = np.array([2, 3, 5, 11])
# array_2 = np.array([1, -4, 2, 0])
#
# # The "+" operation adds the elements of the two arrays together, where it'll be 2+1...
# print(array_1 + array_2)
#
# Math print(2**5) # exponent
# print(np.log(2))
# print(np.exp(2))
# print(np.sin(2))
# print(np.cos(2))
# print(np.sqrt(2))
#
# Graphing
# x_vals = [-1.5, -1.25, -1, -0.75, -0.5, -0.25, 0, 0.25, 0.5, 0.75, 1, 1.25, 1.5]
#
# # Convert to numpy array
# x_vals = np.array(x_vals)
#
# # Create new numpy array with the function evaluated at the same points
# y_vals = x_vals**3 - 2*x_vals + 0.5
#
# # Use plt.scatter to create scatter plot
# plt.scatter(x = x_vals, y = y_vals)
# plt.show()
#
# Lecture 7
#
# Boolean, in keyword:
#
# sentence = "The Federal Reserve makes forecasts about many economic outcomes"
#
# keyword = "economic"
# print(keyword in sentence)
#
# if, elif, else
#
# Lists can be made larger using append
#
# random:
#
# lo = 1
# hi = 20
# random_int = random.randint(lo, hi)
# print(random_int)
#
#
# Lecture 7 supplement
#
# Append, copy, reverse, count, sort, stats:
#
# print(np.mean(c_vec)) # mean
# print(np.std(c_vec)) # standard deviation
# print(np.median(c_vec)) # median
# print(np.max(c_vec)) # maximum
# print(np.min(c_vec)) # minimum
#
# pi = np.pi
#
# making normal distribution graph
#
# # generate 5 samples from a normal distribution with standard deviation = 2.4, and mean = -1
# five_samples = np.random.normal(loc = -1, scale = 2.4, size = 5)
#
# seed
# np.random.seed(0)
#
# # making a normal distribution graph
# np.random.seed(1989)
#
# sample_size = 1000
#
# standard_normal_samples = np.random.normal(size = sample_size)
#
# plt.hist(x = standard_normal_samples)
# plt.xlabel("Values drawn from Distribution")
# plt.ylabel("Frequency")
# plt.title("Histogram of standard normal variable (1,000 samples)")
# plt.show()
#
#
# Lecture 8
#
# for loop:
# good_movies = [] # create empty list
#
# cut_off = 7.0 # minimum rating for "good movie"
#
# movie_titles = ["The Umbrellas of Cherbourg", "M3gan", "Psycho"]
# movie_ratings = [7.8, 6.3, 8.5]
#
# index = 0
#
# for ratings in movie_ratings:
#     title = movie_titles[index]
#     if ratings >= cut_off:
#         good_movies = good_movies + [title]
#
#     index = index + 1
#
# print(good_movies)
#
# zip
#
#
# # while loop
# eps = 0.025
#
# x_list = []
# y_list = []
#
#
# x = 1
# while 1/x > eps:
#     x_list.append(x)
#     y_list.append(1/x)
#     x = x + 1
#
# plt.scatter(x = x_list, y = y_list)
# plt.title("Graph of f(x) = 1/x")
# plt.xlabel('x')
# plt.ylabel("y")
# plt.show()
#
#
# Lecture 9
#
# random variables
