# %%
import pandas as pd

pd.read_csv("GA_regional_status_2023.csv")
pd.read_csv("GA_regional_trends_2023.csv")
# Out:
#     state_name species_code               common_name  \
# 0      Georgia       acafly        Acadian Flycatcher
# 1      Georgia       ambduc       American Black Duck
# 2      Georgia       ameavo           American Avocet
# 3      Georgia       amecro             American Crow
# 4      Georgia       amegfi        American Goldfinch
# ..         ...          ...                       ...
# 226    Georgia       yebcuc      Yellow-billed Cuckoo
# 227    Georgia       yebsap  Yellow-bellied Sapsucker
# 228    Georgia       yelwar            Yellow Warbler
# 229    Georgia       yetvir     Yellow-throated Vireo
# 230    Georgia       yetwar   Yellow-throated Warbler
#
#              scientific_name trend_period  season_code  state_trend_median  \
# 0        Empidonax virescens    2012-2022     breeding                4.63
# 1              Anas rubripes    2012-2022  nonbreeding              -45.20
# 2    Recurvirostra americana    2012-2022     breeding              -50.50
# ...
